# %% [markdown]
# # 🎙️ WhisperX 音頻轉精準對齊字幕工具 (Google Colab 版)
#
# 這個 Notebook 提供了一鍵運行的 WhisperX 字幕生成工具，支援多種語言和字幕格式。

# %% [markdown]
# ## 🚀 一鍵運行
#
# 執行下方儲存格即可啟動工具：

# %%
# 一鍵運行 WhisperX 字幕生成工具
# !wget -q https://raw.githubusercontent.com/你的用戶名/WhisperX_ffmpeg_2_Subtitle/main/WhisperX_ffmpeg_2_Subtitle.py && python WhisperX_ffmpeg_2_Subtitle.py

# %% [markdown]
# ## 📖 使用說明
#
# 1. **選擇音頻來源**：可選擇 Google Drive 中的文件或手動上傳
# 2. **設定參數**：選擇語言、提示詞和模型大小
# 3. **開始轉換**：點擊「開始生成字幕」按鈕
# 4. **下載結果**：處理完成後可下載字幕文件

# %% [markdown]
# ## ⚡ 模型選擇建議
#
# - **Large-v3-Turbo**：推薦！平衡速度與精度，適合大多數情況
# - **Small**：如果顯存不足，可使用此選項
# - **Large-v3**：追求最高精度，但需要較多顯存和時間

# %% [markdown]
# ## 📝 注意事項
#
# - 首次運行會自動安裝依賴，可能需要幾分鐘
# - 如果使用 Large 模型，請確保 Colab 有足夠的 GPU 記憶體（建議使用 T4 或 V100）
# - 處理完成後請及時下載文件，Colab 會話結束後文件會被刪除
